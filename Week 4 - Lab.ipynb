# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# |**Mehrnaz Cecil**|
# |---|
# |Data science|

# %% [markdown]
# *I am interested in Data Science because I believe it is very much in demand and my background, character and mindset will makes me successful in this sexy opportunity*

# %% [markdown]
# ### I give a list of string and it gives a random string back from the list

# %%
import string
import random

str_lst =['Sun','Mercury','Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
print("The name of planets are: ", str_lst)
rand_str =random.choice(str_lst)
print("The random Planet name is: ", rand_str)
# Out:
# The name of planets are:  ['Sun', 'Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
# The random Planet name is:  Neptune

# %% [markdown]
# ### The name of first and last planets distance to sun
#
# ---
# <div class="alert alert-block alert-warning">
# <b>Click on the name of the planet to get Fact Points
# </div>
#
# | Name of the Planet | Distance to Sun (KM) |
# |--|--|
# | [Mercury](https://nssdc.gsfc.nasa.gov/planetary/factsheet/mercuryfact.html) |  69.8 million |
# | [Neptune](https://nssdc.gsfc.nasa.gov/planetary/factsheet/neptunefact.html) | 4.48 bn|
#
# <div class="alert alert-block alert-danger">
# <b> The Picture of Mercury and Neptune are respectively as follow
# </div>
#
#
# `Mercury Image`<br>
# ![Mercury.png](attachment:fb10677e-887d-413b-8edd-d07642b5c053.png)
# `Neptune Image` <br>
# ![Neptune picture.png](attachment:7d3ea9d9-e9bf-48aa-ae4b-5c5f121e551f.png)
